# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("booksc.csv", encoding='ISO-8859-1')
print("🔹 First 5 Rows of Data:\n", df.head(), "\n")
print("🔹 Dataset Shape:", df.shape, "\n")
print("🔹 Data Types:\n", df.dtypes, "\n")
print("🔹 Unique Values per Column:\n", df.nunique(), "\n")
print("🔹 Descriptive Statistics:\n", df.describe(include='all'), "\n")
df['Price'] = df['Price'].replace(r'[^\d.]', '', regex=True).astype(float)

print("🔹 Missing Values:\n", df.isnull().sum(), "\n")

plt.figure(figsize=(10, 6))
sns.histplot(df['Price'], bins=30, kde=True)
plt.title("Distribution of Book Prices")
plt.xlabel("Price")
plt.ylabel("Count")
plt.show()

if 'Category' in df.columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, y='Category', order=df['Category'].value_counts().index)
    plt.title("Top Book Categories")
    plt.xlabel("Count")
    plt.ylabel("Category")
    plt.show()
# Out:
# 🔹 First 5 Rows of Data:
#                                     Title      Price Availability Rating
# 0                   A Light in the Attic  ÃÂ£51.77     In stock  Three
# 1                     Tipping the Velvet  ÃÂ£53.74     In stock    One
# 2                             Soumission  ÃÂ£50.10     In stock    One
# 3                          Sharp Objects  ÃÂ£47.82     In stock   Four
# 4  Sapiens: A Brief History of Humankind  ÃÂ£54.23     In stock   Five
#
# 🔹 Dataset Shape: (1000, 4)
#
# 🔹 Data Types:
#  Title           object
# Price           object
# Availability    object
# Rating          object
# dtype: object
#
# 🔹 Unique Values per Column:
#  Title           999
# Price           903
# Availability      1
# Rating            5
# dtype: int64
#
# 🔹 Descriptive Statistics:
#                           Title      Price Availability Rating
# count                     1000       1000         1000   1000
# unique                     999        903            1      5
# top     The Star-Touched Queen  ÃÂ£37.34     In stock    One
# freq                         2          3         1000    226
#
# 🔹 Missing Values:
#  Title           0
# Price           0
# Availability    0
# Rating          0
# dtype: int64
